# %%
import torch

# %%
mat_a = torch.tensor([0, 3, 5, 5, 5, 2]).view(2, 3)
mat_a
# Out:
# tensor([[0, 3, 5],
#         [5, 5, 2]])

# %%
mat_b = torch.tensor([3, 4, 3, -2, 4, -2]).view(3, 2)
mat_b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mat_b = torch.tensor(3, 4, 3, -2, 4, -2).view(3, 2)
#       2 mat_b
#
# TypeError: tensor() takes 1 positional argument but 6 were given
